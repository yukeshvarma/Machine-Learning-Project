# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
raw=files.upload()
# Out:
#      <input type="file" id="files-1f137e06-3312-4005-898c-748ae1e880ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f137e06-3312-4005-898c-748ae1e880ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('Building_Permits1.csv')
# Out:
# <ipython-input-58-80a0a37c73c9>:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Building_Permits1.csv')

# %% [markdown]
# **EDA-Exploratory Data Analysis**

# %%
df.head(10)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0   2.01505E+11            4                      sign - erect
# 1   2.01604E+11            4                      sign - erect
# 2   2.01605E+11            3  additions alterations or repairs
# 3   2.01611E+11            8            otc alterations permit
# 4   2.01611E+11            6                       demolitions
# 5   2.01706E+11            8            otc alterations permit
# 6   2.01706E+11            8            otc alterations permit
# 7       M803667            8            otc alterations permit
# 8       M804227            8            otc alterations permit
# 9       M804767            8            otc alterations permit
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05-06-2015   326   23            140                  NaN
# 1           04/19/2016   306    7            440                  NaN
# ...

# %%
df.tail()
# Out:
#        Permit Number  Permit Type  Permit Type Definition  \
# 198895       M862628            8  otc alterations permit
# 198896   2.01712E+11            8  otc alterations permit
# 198897       M863507            8  otc alterations permit
# 198898       M863747            8  otc alterations permit
# 198899       M864287            8  otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 198895           12-05-2017   113  017A           1228                  NaN
# 198896           12-05-2017   271    14            580                  NaN
# 198897           12-06-2017  4318    19           1568                  NaN
# 198898           12-06-2017   298    29            795                  NaN
# 198899           12-07-2017   160     6            838                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 198895  Montgomery            St  ...                         NaN
# ...

# %%
df.shape
# Out:
# (198900, 43)

# %%
df['Revised Cost'].value_counts()
# Out:
# 1.000000e+00    47228
# 0.000000e+00     8513
# 1.000000e+04     5474
# 5.000000e+03     5453
# 2.000000e+04     4696
#                 ...
# 3.472800e+04        1
# 2.390000e+08        1
# 1.712600e+04        1
# 2.034000e+03        1
# 1.845312e+04        1
# Name: Revised Cost, Length: 12629, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   Permit Number                           198900 non-null  object
#  1   Permit Type                             198900 non-null  int64
#  2   Permit Type Definition                  198900 non-null  object
#  3   Permit Creation Date                    198900 non-null  object
#  4   Block                                   198900 non-null  object
#  5   Lot                                     198900 non-null  object
#  6   Street Number                           198900 non-null  int64
#  7   Street Number Suffix                    2216 non-null    object
#  8   Street Name                             198900 non-null  object
#  9   Street Suffix                           196132 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Permit Number', 'Permit Type', 'Permit Type Definition',
#        'Permit Creation Date', 'Block', 'Lot', 'Street Number',
#        'Street Number Suffix', 'Street Name', 'Street Suffix', 'Unit',
#        'Unit Suffix', 'Description', 'Current Status', 'Current Status Date',
#        'Filed Date', 'Issued Date', 'Completed Date',
#        'First Construction Document Date', 'Structural Notification',
#        'Number of Existing Stories', 'Number of Proposed Stories',
#        'Voluntary Soft-Story Retrofit', 'Fire Only Permit',
#        'Permit Expiration Date', 'Estimated Cost', 'Revised Cost',
#        'Existing Use', 'Existing Units', 'Proposed Use', 'Proposed Units',
#        'Plansets', 'TIDF Compliance', 'Existing Construction Type',
#        'Existing Construction Type Description', 'Proposed Construction Type',
#        'Proposed Construction Type Description', 'Site Permit',
#        'Supervisor District', 'Neighborhoods - Analysis Boundaries', 'Zipcode',
# ...

# %%
df.describe()
# Out:
#          Permit Type  Street Number          Unit  Number of Existing Stories  \
# count  198900.000000  198900.000000  29479.000000               156116.000000
# mean        7.522323    1121.728944     78.517182                    5.705773
# std         1.457451    1135.768948    326.981324                    8.613455
# min         1.000000       0.000000      0.000000                    0.000000
# 25%         8.000000     235.000000      0.000000                    2.000000
# 50%         8.000000     710.000000      0.000000                    3.000000
# 75%         8.000000    1700.000000      1.000000                    4.000000
# max         8.000000    8400.000000   6004.000000                   78.000000
#
#        Number of Proposed Stories  Estimated Cost  Revised Cost  \
# count               156032.000000    1.608340e+05  1.928340e+05
# mean                     5.745043    1.689554e+05  1.328562e+05
# std                      8.613284    3.630386e+06  3.584903e+06
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
df.isnull().sum()
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %%
df.shape #85,52,700
# Out:
# (198900, 43)

# %%
print('Existing Units :',51538/198900*100)
print('Structural Notification :',191978/198900*100)
print('Voluntary Soft-Story Retrofit:',198865/198900*100)
print('Fire Only Permit:',180073/198900*100)
print('Site Permit :', 193541/198900*100)
# Out:
# Existing Units : 25.91151332327803
# Structural Notification : 96.51985922574158
# Voluntary Soft-Story Retrofit: 99.98240321769734
# Fire Only Permit: 90.53443941679235
# Site Permit : 97.30568124685772

# %%
dfx=df.copy()

# %%
dfx.shape
# Out:
# (198900, 43)

# %%
df=df.drop(columns=['Permit Number','Permit Creation Date', 'Lot', 'Street Number',
       'Street Number Suffix', 'Street Name', 'Street Suffix', 'Unit',
       'Unit Suffix','Current Status Date',
       'Filed Date', 'Issued Date', 'Completed Date',
       'First Construction Document Date','Permit Expiration Date', 'Zipcode',
       'Location', 'Record ID','Block','Description','Neighborhoods - Analysis Boundaries','Existing Construction Type Description','Proposed Construction Type Description'])

# %%
df.columns
# Out:
# Index(['Permit Type', 'Permit Type Definition', 'Current Status',
#        'Structural Notification', 'Number of Existing Stories',
#        'Number of Proposed Stories', 'Voluntary Soft-Story Retrofit',
#        'Fire Only Permit', 'Estimated Cost', 'Revised Cost', 'Existing Use',
#        'Existing Units', 'Proposed Use', 'Proposed Units', 'Plansets',
#        'TIDF Compliance', 'Existing Construction Type',
#        'Proposed Construction Type', 'Site Permit', 'Supervisor District'],
#       dtype='object')

# %%
df.shape
# Out:
# (198900, 20)

# %%
#i chosen Supervisor District as y

# %%
dfxy=df.dropna(subset=['Supervisor District'])

# %%
dfxy.shape
# Out:
# (198900, 15)

# %%
dfxy=dfxy.drop(columns=['Permit Type Definition'])

# %%
dfxy=df.drop(columns=['Voluntary Soft-Story Retrofit', 'Fire Only Permit','Structural Notification','TIDF Compliance','Site Permit'])#because of too many nan values in data#['Supervisor District'])

# %%
dfxy['Supervisor District'].isnull().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
dfxy['Current Status']=lb.fit_transform(dfxy['Current Status'])#ask mam ,how to encode multiple columns
dfxy['Existing Use']=lb.fit_transform(dfxy['Existing Use'])
dfxy['Proposed Use']=lb.fit_transform(dfxy['Proposed Use'])

# %%
dfxy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198900 entries, 0 to 198899
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Permit Type                 198900 non-null  int64
#  1   Current Status              198900 non-null  int64
#  2   Number of Existing Stories  156116 non-null  float64
#  3   Number of Proposed Stories  156032 non-null  float64
#  4   Estimated Cost              160834 non-null  float64
#  5   Revised Cost                192834 non-null  float64
#  6   Existing Use                198900 non-null  int64
#  7   Existing Units              147362 non-null  float64
#  8   Proposed Use                198900 non-null  int64
#  9   Proposed Units              147989 non-null  float64
#  10  Plansets                    161591 non-null  float64
#  11  Existing Construction Type  155534 non-null  float64
# ...

# %% [markdown]
# i choose iterativeimputer instead of fillna bcz of multiple values to entered

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# %%
iterative = IterativeImputer()

# %%
dfxy.iloc[:,:]=iterative.fit_transform(dfxy)
# Out:
# <ipython-input-113-679f30403a1f>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfxy.iloc[:,:]=iterative.fit_transform(dfxy)

# %%
dfxy.isnull().sum()
# Out:
# Permit Type                   0
# Current Status                0
# Number of Existing Stories    0
# Number of Proposed Stories    0
# Estimated Cost                0
# Revised Cost                  0
# Existing Use                  0
# Existing Units                0
# Proposed Use                  0
# Proposed Units                0
# Plansets                      0
# Existing Construction Type    0
# Proposed Construction Type    0
# Supervisor District           0
# dtype: int64

# %%
dfxy.head()
# Out:
#    Permit Type  Current Status  Number of Existing Stories  \
# 0          4.0             5.0                         6.0
# 1          4.0             8.0                         7.0
# 2          3.0            13.0                         6.0
# 3          8.0             3.0                         2.0
# 4          6.0             8.0                         3.0
#
#    Number of Proposed Stories  Estimated Cost   Revised Cost  Existing Use  \
# 0                    1.046006          4000.0    4000.000000          85.0
# 1                    5.642560             1.0     500.000000          85.0
# 2                    6.000000         20000.0   26068.445912          71.0
# 3                    2.000000          2000.0    2000.000000           0.0
# 4                    1.534078        100000.0  100000.000000          71.0
#
#    Existing Units  Proposed Use  Proposed Units  Plansets  \
# 0      143.000000          94.0       70.744065       2.0
# ...
