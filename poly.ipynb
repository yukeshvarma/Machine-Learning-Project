# %%
from google.colab import files
raw=files.upload()
# Out:
#      <input type="file" id="files-52a42462-57a5-4859-b5c2-8c25eac704b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52a42462-57a5-4859-b5c2-8c25eac704b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('Gaming_data (1).csv')

# %%
df.head()
# Out:
#    Steps  Points
# 0      1   45000
# 1      2   50000
# 2      3   60000
# 3      4   80000
# 4      5  110000

# %%
df.tail()
# Out:
#    Steps   Points
# 5      6   150000
# 6      7   200000
# 7      8   300000
# 8      9   500000
# 9     10  1000000

# %%
df.shape
# Out:
# (10, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Steps   10 non-null     int64
#  1   Points  10 non-null     int64
# dtypes: int64(2)
# memory usage: 288.0 bytes

# %%
df.describe()
# Out:
#           Steps          Points
# count  10.00000       10.000000
# mean    5.50000   249500.000000
# std     3.02765   299373.883668
# min     1.00000    45000.000000
# 25%     3.25000    65000.000000
# 50%     5.50000   130000.000000
# 75%     7.75000   275000.000000
# max    10.00000  1000000.000000

# %%
df.isnull().sum()
# Out:
# Steps     0
# Points    0
# dtype: int64

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1:]

# %%
#from sklearn.model_selection import train_test_split #doubt need to ask

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.27,random_state=131)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(x,y)
predict=regressor.predict(x)

# %%
#regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction=regressor.predict(x_test)

# %%
predict
# Out:
# array([[-114454.54545455],
#        [ -33575.75757576],
#        [  47303.03030303],
#        [ 128181.81818182],
#        [ 209060.60606061],
#        [ 289939.39393939],
#        [ 370818.18181818],
#        [ 451696.96969697],
#        [ 532575.75757576],
#        [ 613454.54545455]])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.plot(x,predict,color='red')
plt.xlabel('step')
plt.ylabel('points')
plt.title('try pandre')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=6)

# %%
X_poly=poly.fit_transform(x)
poly_lr=LinearRegression()

# %%
poly_lreg=poly_lr.fit(X_poly,y)

# %%
predict2 = poly_lreg.predict(X_poly)

# %%
X_poly
# Out:
# array([[1.00000e+00, 1.00000e+00, 1.00000e+00, 1.00000e+00, 1.00000e+00,
#         1.00000e+00, 1.00000e+00],
#        [1.00000e+00, 2.00000e+00, 4.00000e+00, 8.00000e+00, 1.60000e+01,
#         3.20000e+01, 6.40000e+01],
#        [1.00000e+00, 3.00000e+00, 9.00000e+00, 2.70000e+01, 8.10000e+01,
#         2.43000e+02, 7.29000e+02],
#        [1.00000e+00, 4.00000e+00, 1.60000e+01, 6.40000e+01, 2.56000e+02,
#         1.02400e+03, 4.09600e+03],
#        [1.00000e+00, 5.00000e+00, 2.50000e+01, 1.25000e+02, 6.25000e+02,
#         3.12500e+03, 1.56250e+04],
#        [1.00000e+00, 6.00000e+00, 3.60000e+01, 2.16000e+02, 1.29600e+03,
#         7.77600e+03, 4.66560e+04],
#        [1.00000e+00, 7.00000e+00, 4.90000e+01, 3.43000e+02, 2.40100e+03,
#         1.68070e+04, 1.17649e+05],
#        [1.00000e+00, 8.00000e+00, 6.40000e+01, 5.12000e+02, 4.09600e+03,
#         3.27680e+04, 2.62144e+05],
#        [1.00000e+00, 9.00000e+00, 8.10000e+01, 7.29000e+02, 6.56100e+03,
# ...

# %%
plt.scatter(x,y)
plt.plot(x,predict2,color='yellow')
plt.title('tried best')
plt.xlabel('steps')
plt.ylabel('point')
plt.show()
