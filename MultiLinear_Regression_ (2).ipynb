# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
studata = files.upload()
# Out:
#      <input type="file" id="files-1a0e2d96-52ad-4338-9bf6-de2acaa03ee2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a0e2d96-52ad-4338-9bf6-de2acaa03ee2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
studf=pd.read_excel('schoolstudents.xlsx')

# %%
studf
# Out:
#     Age  Weight (kg)  Height (cm)  Standard
# 0    17           60          170        11
# 1     7           25          120         2
# 2    16           55          165        10
# 3    18           70          175        12
# 4     7           25          120         2
# 5    11           35          140         5
# 6     8           30          125         3
# 7    10           33          135         4
# 8    15           50          160         9
# 9    14           45          155         8
# 10   18           70          175        12
# 11   14           45          155         8
# 12   12           40          145         6
# 13    8           30          125         3
# 14   18           70          175        12
# 15   15           50          160         9
# 16   16           55          165        10
# 17   15           50          160         9
# 18   16           55          165        10
# 19    8           30          125         3
# ...

# %%
studf.describe()
# Out:
#              Age  Weight (kg)  Height (cm)   Standard
# count  24.000000    24.000000    24.000000  24.000000
# mean   13.375000    46.750000   151.333333   7.625000
# std     4.062688    15.146387    19.837748   3.692678
# min     7.000000    25.000000   120.000000   2.000000
# 25%     9.500000    32.250000   132.500000   3.750000
# 50%    15.000000    50.000000   160.000000   9.000000
# 75%    16.250000    55.000000   165.000000  10.250000
# max    18.000000    70.000000   175.000000  12.000000

# %%
x=studf.iloc[:,:-1].values  #start to end

# %%
x
# Out:
# array([[ 17,  60, 170],
#        [  7,  25, 120],
#        [ 16,  55, 165],
#        [ 18,  70, 175],
#        [  7,  25, 120],
#        [ 11,  35, 140],
#        [  8,  30, 125],
#        [ 10,  33, 135],
#        [ 15,  50, 160],
#        [ 14,  45, 155],
#        [ 18,  70, 175],
#        [ 14,  45, 155],
#        [ 12,  40, 145],
#        [  8,  30, 125],
#        [ 18,  70, 175],
#        [ 15,  50, 160],
#        [ 16,  55, 165],
#        [ 15,  50, 160],
#        [ 16,  55, 165],
#        [  8,  30, 125],
#        [  7,  25, 120],
#        [ 18,  70, 175],
#        [ 15,  50, 160],
#        [ 18,  54, 162]])

# %%
y =studf.iloc[:,3:4].values

# %%
y
# Out:
# array([[11],
#        [ 2],
#        [10],
#        [12],
#        [ 2],
#        [ 5],
#        [ 3],
#        [ 4],
#        [ 9],
#        [ 8],
#        [12],
#        [ 8],
#        [ 6],
#        [ 3],
#        [12],
#        [ 9],
#        [10],
#        [ 9],
#        [10],
#        [ 3],
#        [ 2],
#        [12],
#        [ 9],
#        [12]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=13)

# %%
x_train.shape
# Out:
# (16, 3)

# %%
from sklearn.linear_model import LinearRegression

# %%
s_regression = LinearRegression()

# %%
s_regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
result = s_regression.predict(x_test)

# %%
s_regression.predict([[ 26,  55, 182]])
# Out:
# array([[18.94709502]])

# %%
y_test
# Out:
# array([[ 9],
#        [ 2],
#        [ 4],
#        [ 9],
#        [ 8],
#        [ 2],
#        [11],
#        [ 3]])

# %%
result
# Out:
# array([[ 8.92705882],
#        [ 1.94      ],
#        [ 4.49576471],
#        [ 8.92705882],
#        [ 7.96588235],
#        [ 1.94      ],
#        [10.84941176],
#        [ 2.90117647]])

# %%
studf
# Out:
#     Age  Weight (kg)  Height (cm)  Standard
# 0    17           60          170        11
# 1     7           25          120         2
# 2    16           55          165        10
# 3    18           70          175        12
# 4     7           25          120         2
# 5    11           35          140         5
# 6     8           30          125         3
# 7    10           33          135         4
# 8    15           50          160         9
# 9    14           45          155         8
# 10   18           70          175        12
# 11   14           45          155         8
# 12   12           40          145         6
# 13    8           30          125         3
# 14   18           70          175        12
# 15   15           50          160         9
# 16   16           55          165        10
# 17   15           50          160         9
# 18   16           55          165        10
# 19    8           30          125         3
# ...

# %%
error = result-y_test

# %%
error
# Out:
# array([[-0.07294118],
#        [-0.06      ],
#        [ 0.49576471],
#        [-0.07294118],
#        [-0.03411765],
#        [-0.06      ],
#        [-0.15058824],
#        [-0.09882353]])
